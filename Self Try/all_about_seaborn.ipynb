# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../Pandas Dataset/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')>

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Joinplot

# %%
sns.jointplot(x="population",y="total_rooms",data=df)

# %%
df=pd.read_csv('../Pandas Dataset/titanic_info_test.csv')
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Countplot

# %%
sns.countplot(x="Embarked",data=df) #specofuy which should be in x axis, and the count of those catagorical data will be plotted
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Barplot

# %%
sns.barplot(x="Embarked",y="Fare",data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x="Sex",y="Fare",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x="Sex",y="Fare",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>
