# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../Pandas Dataset/cereal.csv")
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
x=df.groupby(by="type")
x.value_counts()
# Out:
# type  name                    mfr  calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  rating
# C     100% Bran               N    70        4        1    130     10.0    5.0    6       280    25        3      1.00    0.33  68.402973    1
#       Oatmeal Raisin Crisp    G    130       3        2    170     1.5     13.5   10      120    25        3      1.25    0.50  30.450843    1
#       Raisin Nut Bran         G    100       3        2    140     2.5     10.5   8       140    25        3      1.00    0.50  39.703400    1
#       Raisin Bran             K    120       3        1    210     5.0     14.0   12      240    25        2      1.33    0.75  39.259197    1
#       Quaker Oat Squares      Q    100       4        1    135     2.0     14.0   6       110    25        3      1.00    0.50  49.511874    1
# ...

# %%
plt.plot(df["fat"],np.zeros_like(df["fat"]),"o")

# %%
sns.FacetGrid(df,col="type").map(plt.scatter,"calories","shelf").add_legend()

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')>

# %%
sns.pairplot(df[['calories','shelf', 'weight', 'cups','rating']])
